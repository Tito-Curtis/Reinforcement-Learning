# %%
import pandas as pd

# %%
df = pd.read_csv('data/HESS_Dataset.csv')

# %%
df
# Out:
#                Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 0    2024-04-01 00:00:00       18.727006       7.405317       8.925585
# 1    2024-04-01 01:00:00       47.535715      21.676038       8.704682
# 2    2024-04-01 02:00:00       36.599697      34.917833      18.593819
# 3    2024-04-01 03:00:00       29.932924      29.288995       8.743193
# 4    2024-04-01 04:00:00        7.800932      32.262446       9.079246
# ..                   ...             ...            ...            ...
# 995  2024-05-12 11:00:00        4.579104      26.278206      17.979436
# 996  2024-05-12 12:00:00       45.865679      38.264585       7.359098
# 997  2024-05-12 13:00:00        6.840932       2.758321       9.646818
# 998  2024-05-12 14:00:00       47.511868       2.282189       9.350683
# 999  2024-05-12 15:00:00       22.300289      11.287483      18.071211
#
#      Battery_SoC_%  SC_Charge_kW  Hydrogen_Production_kg/h  Load_Demand_kW  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Solar_Power_kW', 'Wind_Power_kW', 'Grid_Power_kW',
#        'Battery_SoC_%', 'SC_Charge_kW', 'Hydrogen_Production_kg/h',
#        'Load_Demand_kW', 'Power_Supplied_kW', 'Power_Loss_kW',
#        'Optimization_Level'],
#       dtype='object')

# %%
df.Optimization_Level.unique()
# Out:
# array(['High Efficiency', 'Moderate Efficiency', 'Low Efficiency'],
#       dtype=object)

# %%
df[df.Optimization_Level == 'Low Efficiency']
# Out:
#                Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 27   2024-04-02 03:00:00       25.711722      33.781976      19.719456
# 120  2024-04-06 00:00:00       40.372008      35.549923      17.054053
# 152  2024-04-07 08:00:00        7.244744      27.898858      15.680210
# 153  2024-04-07 09:00:00       24.472638      27.205631      17.389673
# 199  2024-04-09 07:00:00       38.993777       5.203450      10.706008
# 204  2024-04-09 12:00:00       30.321453      19.545728      16.098562
# 253  2024-04-11 13:00:00       15.846100       5.007432      17.439302
# 319  2024-04-14 07:00:00       12.512145       2.414083      11.165316
# 382  2024-04-16 22:00:00       31.447142      38.776493      18.749529
# 497  2024-04-21 17:00:00        3.886732      18.539762      17.983657
# 721  2024-05-01 01:00:00        9.061653       4.855398      16.747976
# 905  2024-05-08 17:00:00       44.633586       8.099222       5.819516
# ...

# %%
battery_df = pd.read_csv("data/HESS_Dataset_enriched.csv")

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
battery_df['Timestamp'] = pd.to_datetime(battery_df['Timestamp'])

# %%
battery_df
# Out:
#               Timestamp  Battery_Charge_kW  Battery_Discharge_kW  \
# 0   2024-01-01 00:00:00          22.483571             21.996777
# 1   2024-01-01 01:00:00          19.308678             19.623168
# 2   2024-01-01 02:00:00          23.238443             15.298152
# 3   2024-01-01 03:00:00          27.615149             11.765316
# 4   2024-01-01 04:00:00          18.829233             18.491117
# ..                  ...                ...                   ...
# 995 2024-02-11 11:00:00          18.594499             20.350751
# 996 2024-02-11 12:00:00          28.988433             14.867394
# 997 2024-02-11 13:00:00          23.204214             10.590627
# 998 2024-02-11 14:00:00          17.144105             14.184665
# 999 2024-02-11 15:00:00          22.862914             11.275487
#
#      SC_Charge_kW  SC_Discharge_kW  hour  Electricity_Price_USDperkWh  \
# 0        3.649643         0.184385     0                          0.1
# ...

# %%
battery_df['Timestamp'] = df['Timestamp']

# %%
df['Timestamp'][0:10]
# Out:
# 0   2024-04-01 00:00:00
# 1   2024-04-01 01:00:00
# 2   2024-04-01 02:00:00
# 3   2024-04-01 03:00:00
# 4   2024-04-01 04:00:00
# 5   2024-04-01 05:00:00
# 6   2024-04-01 06:00:00
# 7   2024-04-01 07:00:00
# 8   2024-04-01 08:00:00
# 9   2024-04-01 09:00:00
# Name: Timestamp, dtype: datetime64[ns]

# %%
merged_df = pd.merge(df,battery_df,how='inner',on='Timestamp')

# %%
merged_df
# Out:
#               Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 0   2024-04-01 00:00:00       18.727006       7.405317       8.925585
# 1   2024-04-01 01:00:00       47.535715      21.676038       8.704682
# 2   2024-04-01 02:00:00       36.599697      34.917833      18.593819
# 3   2024-04-01 03:00:00       29.932924      29.288995       8.743193
# 4   2024-04-01 04:00:00        7.800932      32.262446       9.079246
# ..                  ...             ...            ...            ...
# 995 2024-05-12 11:00:00        4.579104      26.278206      17.979436
# 996 2024-05-12 12:00:00       45.865679      38.264585       7.359098
# 997 2024-05-12 13:00:00        6.840932       2.758321       9.646818
# 998 2024-05-12 14:00:00       47.511868       2.282189       9.350683
# 999 2024-05-12 15:00:00       22.300289      11.287483      18.071211
#
#      Battery_SoC_%  SC_Charge_kW_x  Hydrogen_Production_kg/h  Load_Demand_kW  \
# ...

# %%
a = merged_df['Optimization_Level']

# %%
merged_df = merged_df.drop("Optimization_Level",axis=1)

# %%
merged_df
# Out:
#               Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 0   2024-04-01 00:00:00       18.727006       7.405317       8.925585
# 1   2024-04-01 01:00:00       47.535715      21.676038       8.704682
# 2   2024-04-01 02:00:00       36.599697      34.917833      18.593819
# 3   2024-04-01 03:00:00       29.932924      29.288995       8.743193
# 4   2024-04-01 04:00:00        7.800932      32.262446       9.079246
# ..                  ...             ...            ...            ...
# 995 2024-05-12 11:00:00        4.579104      26.278206      17.979436
# 996 2024-05-12 12:00:00       45.865679      38.264585       7.359098
# 997 2024-05-12 13:00:00        6.840932       2.758321       9.646818
# 998 2024-05-12 14:00:00       47.511868       2.282189       9.350683
# 999 2024-05-12 15:00:00       22.300289      11.287483      18.071211
#
#      Battery_SoC_%  SC_Charge_kW_x  Hydrogen_Production_kg/h  Load_Demand_kW  \
# ...

# %%
merged_df.to_csv("Optimization.csv",index=False)

# %%
pd.read_csv("Optimization.csv")
# Out:
#                Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 0    2024-04-01 00:00:00       18.727006       7.405317       8.925585
# 1    2024-04-01 01:00:00       47.535715      21.676038       8.704682
# 2    2024-04-01 02:00:00       36.599697      34.917833      18.593819
# 3    2024-04-01 03:00:00       29.932924      29.288995       8.743193
# 4    2024-04-01 04:00:00        7.800932      32.262446       9.079246
# ..                   ...             ...            ...            ...
# 995  2024-05-12 11:00:00        4.579104      26.278206      17.979436
# 996  2024-05-12 12:00:00       45.865679      38.264585       7.359098
# 997  2024-05-12 13:00:00        6.840932       2.758321       9.646818
# 998  2024-05-12 14:00:00       47.511868       2.282189       9.350683
# 999  2024-05-12 15:00:00       22.300289      11.287483      18.071211
#
#      Battery_SoC_%  SC_Charge_kW_x  Hydrogen_Production_kg/h  Load_Demand_kW  \
# ...
